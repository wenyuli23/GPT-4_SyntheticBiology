# %% [markdown]
# # Data preprocessing & extraction

# %% [markdown]
# This part does the following:
# - Splitting data
# - imputate numerical data & encode categorical data
# - generate data overview figures
# - scaling

# %% [markdown]
# ## Rhodosporidium Toruloides

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("../data/RT_raw.xlsx", header=1)
print(df.info())

target = 'Product titer (g/L)'
species = 'Rhodo'
if_scale = False

# Count the semicolons in 'genes_modified_updated'
df['Genes modified'] = df['Genes modified'].fillna('').apply(lambda x: x.count(';'))

# Count the ones in 'gene_overexpression' and 'heterologous_gene'
df['Genes overexpressed'] = df['Genes overexpressed'].fillna('').apply(lambda x: str(x).count('1'))
df['Heterologous genes'] = df['Heterologous genes'].fillna('').apply(lambda x: str(x).count('1'))
df['Genes deleted'] = df['Genes deleted'].fillna('').apply(lambda x: str(x).count('1'))

df = df.drop(['dataID', 'paper_number','product_name'], axis=1)

# Impute all NaN data as zero
imputer = SimpleImputer(strategy='constant', fill_value=0)
df_imputed = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

# correlation plot
f, ax = plt.subplots()

plt.rcParams["figure.figsize"] = [10, 10]
plt.rcParams["figure.autolayout"] = True

corr = df_imputed.corr()
corr_matrix = sns.heatmap(corr,
    cmap=sns.diverging_palette(220, 10, as_cmap=True),
    vmin=-1.0, vmax=1.0,
    square=True, ax=ax)
corr_matrix.figure.savefig(f"../figures/{species}_corr.png", dpi=200)

# scaling
if if_scale:
    scaler = MinMaxScaler()
    df_scaled = pd.DataFrame(scaler.fit_transform(df_imputed), columns=df_imputed.columns)
    X = df_scaled.drop(target, axis=1)
    y = df_scaled[target]
    X_plot = X
    X_plot['plot'] = df_imputed['Product class']
    for train_index, test_index in split.split(X, product_class):
        X_train, X_test = X_plot.iloc[train_index], X_plot.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
else:
    X = df_imputed.drop(target, axis=1)
    y = df_imputed[target]
    for train_index, test_index in split.split(X, product_class):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
# extract product class for plotting
product_class = df_imputed['Product class']
product_class.to_csv(f"../data/{species}_product_class.csv")

# to csv
if if_scale:
    X_train.to_csv(f"../data/{species}_xtrain_scaled.csv")
    X_test.to_csv(f"../data/{species}_xtest_scaled.csv")
    y_train.to_csv(f"../data/{species}_ytrain_scaled.csv")
    y_test.to_csv(f"../data/{species}_ytest_scaled.csv")
else:
    X_train.to_csv(f"../data/{species}_xtrain.csv")
    X_test.to_csv(f"../data/{species}_xtest.csv")
    y_train.to_csv(f"../data/{species}_ytrain.csv")
    y_test.to_csv(f"../data/{species}_ytest.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 32 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   dataID                                             443 non-null    int64
#  1   paper_number                                       0 non-null      float64
#  2   Carbon source 1 (category)                         443 non-null    float64
#  3   Carbon source 1 (g/L)                              420 non-null    float64
#  4   Carbon source 1 heat of combustion (kJ/mol)        443 non-null    float64
#  5   Carbon source 1 heat of combustion (kJ/g)          443 non-null    float64
#  6   Carbon source 2 (category)                         83 non-null     float64
#  7   Carbon source 2 (g/L)                              74 non-null     float64
#  8   Carbon source 2 heat of combustion (kJ/mol)        27 non-null     float64
#  9   Carbon source 2 heat of combustion (kJ/g)          27 non-null     float64
#  10  product_name                                       443 non-null    object
#  11  Product class                                      443 non-null    int64
#  12  Product Gibbs energy of formation in Equilibrator  418 non-null    float64
#  13  Number of carbon atoms in the product              422 non-null    float64
#  14  Number of hydrogen atoms in the product            422 non-null    float64
#  15  Number of oxygen atoms in the product              422 non-null    float64
#  16  MW of product (g/mol)                              407 non-null    float64
#  17  Product titer (g/L)                                443 non-null    float64
#  18  Fermentation time (h)                              443 non-null    int64
#  19  Pathway enzymatic steps                            403 non-null    float64
#  20  ATP cost                                           403 non-null    float64
#  21  NADH or NADPH cost                                 403 non-null    float64
#  22  Reactor type                                       442 non-null    float64
#  23  Cultivation volume (L)                             243 non-null    float64
#  24  Medium type                                        148 non-null    float64
#  25  Temperature                                        441 non-null    float64
#  26  pH                                                 342 non-null    float64
#  27  Estimation of N2 levels                            439 non-null    float64
#  28  Genes modified                                     0 non-null      float64
#  29  Genes deleted                                      0 non-null      float64
#  30  Genes overexpressed                                0 non-null      float64
#  31  Heterologous genes                                 0 non-null      float64
# dtypes: float64(28), int64(3), object(1)
# memory usage: 110.9+ KB
# None

# %% [markdown]
# ## Yarrowia Lipolytica

# %%
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit

df = pd.read_excel("../data/YL_raw.xlsx", sheet_name="data", header=1)
print(df.info())

target = 'Product titer (g/L)'
species = 'Yarrowia'
if_scale = False

# Count the semicolons in 'genes_modified_updated'
df['Genes modified'] = df['Genes modified'].fillna('').apply(lambda x: x.count(';'))

# Count the ones in 'gene_overexpression' and 'heterologous_gene'
df['Genes overexpressed'] = df['Genes overexpressed'].fillna('').apply(lambda x: str(x).count('1'))
df['Heterologous genes'] = df['Heterologous genes'].fillna('').apply(lambda x: str(x).count('1'))
df['Genes deleted'] = df['Genes deleted'].fillna('').apply(lambda x: str(x).count('1'))

df = df.drop(['dataID', 'paper_number','product_name'], axis=1)

# Impute all NaN data as zero
imputer = SimpleImputer(strategy='constant', fill_value=0)
df_imputed = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

# correlation plot
f, ax = plt.subplots()

plt.rcParams["figure.figsize"] = [10, 10]
plt.rcParams["figure.autolayout"] = True

corr = df_imputed.corr()

corr_matrix = sns.heatmap(corr,
    cmap=sns.diverging_palette(220, 10, as_cmap=True),
    vmin=-1.0, vmax=1.0,
    square=True, ax=ax)
corr_matrix.figure.savefig(f"../figures/{species}_corr.png", dpi=200)

# scaling
if if_scale:
    scaler = MinMaxScaler()
    df_scaled = pd.DataFrame(scaler.fit_transform(df_imputed), columns=df_imputed.columns)
    X = df_scaled.drop(target, axis=1)
    y = df_scaled[target]
    X_plot = X
    X_plot['plot'] = df_imputed['Product class']
    for train_index, test_index in split.split(X, product_class):
        X_train, X_test = X_plot.iloc[train_index], X_plot.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
else:
    X = df_imputed.drop(target, axis=1)
    y = df_imputed[target]
    for train_index, test_index in split.split(X, product_class):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
# extract product class for plotting
product_class = df_imputed['Product class']
product_class.to_csv(f"../data/{species}_product_class.csv")

# to csv
if if_scale:
    X_train.to_csv(f"../data/{species}_xtrain_scaled.csv")
    X_test.to_csv(f"../data/{species}_xtest_scaled.csv")
    y_train.to_csv(f"../data/{species}_ytrain_scaled.csv")
    y_test.to_csv(f"../data/{species}_ytest_scaled.csv")
else:
    X_train.to_csv(f"../data/{species}_xtrain.csv")
    X_test.to_csv(f"../data/{species}_xtest.csv")
    y_train.to_csv(f"../data/{species}_ytrain.csv")
    y_test.to_csv(f"../data/{species}_ytest.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4690 entries, 0 to 4689
# Data columns (total 32 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   dataID                                             4690 non-null   int64
#  1   paper_number                                       4690 non-null   object
#  2   Carbon source 1 (category)                         4690 non-null   float64
#  3   Carbon source 1 (g/L)                              4681 non-null   float64
#  4   Carbon source 1 heat of combustion (kJ/mol)        4690 non-null   float64
#  5   Carbon source 1 heat of combustion (kJ/g)          4690 non-null   float64
#  6   Carbon source 2 (category)                         3385 non-null   float64
#  7   Carbon source 2 (g/L)                              3385 non-null   float64
#  8   Carbon source 2 heat of combustion (kJ/mol)        3385 non-null   float64
#  9   Carbon source 2 heat of combustion (kJ/g)          610 non-null    float64
#  10  product_name                                       4690 non-null   object
#  11  Product class                                      4690 non-null   int64
#  12  Product Gibbs energy of formation in Equilibrator  4683 non-null   float64
#  13  Number of carbon atoms in the product              4690 non-null   float64
#  14  Number of hydrogen atoms in the product            4690 non-null   float64
#  15  Number of oxygen atoms in the product              4690 non-null   float64
#  16  MW of product (g/mol)                              4358 non-null   float64
#  17  Product titer (g/L)                                4690 non-null   float64
#  18  Fermentation time (h)                              4690 non-null   float64
#  19  Pathway enzymatic steps                            4262 non-null   float64
#  20  ATP cost                                           4262 non-null   float64
#  21  NADH or NADPH cost                                 4262 non-null   float64
#  22  Reactor type                                       4690 non-null   int64
#  23  Cultivation volume (L)                             4689 non-null   float64
#  24  Medium type                                        4690 non-null   int64
#  25  Temperature                                        4686 non-null   float64
#  26  pH                                                 2725 non-null   float64
#  27  Estimation of N2 levels                            4689 non-null   float64
#  28  Genes modified                                     2994 non-null   object
#  29  Genes deleted                                      2985 non-null   object
#  30  Genes overexpressed                                2992 non-null   object
#  31  Heterologous genes                                 2994 non-null   object
# dtypes: float64(22), int64(4), object(6)
# memory usage: 1.1+ MB
# None
