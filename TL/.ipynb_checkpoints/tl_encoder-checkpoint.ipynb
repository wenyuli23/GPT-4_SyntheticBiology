# %% [markdown]
# ## Pretrained Encoder (keras)

# %%
import logging
import pandas as pd
import numpy as np
import pyreadstat
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import tensorflow as tf
from keras.layers import Dense
from keras.models import Sequential, load_model
from keras.optimizers import SGD
from matplotlib import pyplot

# summarize the performance of the fit model
def summarize_model(model, history, trainX, trainy, testX, testy, figname):
    # evaluate the model
    _, train_acc = model.evaluate(trainX, trainy, verbose=0)
    _, test_acc = model.evaluate(testX, testy, verbose=0)
    print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
    # plot loss during training
    pyplot.subplot(211)
    pyplot.title('MSE')
    pyplot.plot(history.history['loss'], label='train')
    pyplot.plot(history.history['val_loss'], label='test')
    pyplot.legend()
    # plot accuracy during training
    pyplot.subplot(212)
    pyplot.title('R2')
    pyplot.plot(history.history['coeff_determination'], label='train')
    pyplot.plot(history.history['val_coeff_determination'], label='test')
    pyplot.legend()
    pyplot.savefig(figname, dpi=300)
    pyplot.show()

# standalone MLP
def fit_model(trainX, trainy, testX, testy):
    # define model
    model = Sequential()
    model.add(Dense(50, input_dim=28, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dense(28, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dense(14, activation='relu', kernel_initializer='he_uniform'))
    model.summary()
    # compile model
    model.compile(loss= "mean_squared_error" , optimizer="adam", metrics=[tf.keras.metrics.MeanAbsolutePercentageError()])
    # fit model
    history = model.fit(trainX.values, trainy.values, validation_data=(testX.values, testy), epochs=100, verbose=1)
    return model, history

# %%
to_predict = 'Product titer (g/L)'
species = 'YL'
if_scale = False

# source
if if_scale:
    x_train_source = pd.read_csv(f'../data/{species}_xtrain_scaled.csv', index_col=0)
    y_train_source = pd.read_csv(f'../data/{species}_ytrain_scaled.csv', index_col=0).squeeze()
    x_test_source = pd.read_csv(f'../data/{species}_xtest_scaled.csv', index_col=0)
    y_test_source = pd.read_csv(f'../data/{species}_ytest_scaled.csv', index_col=0).squeeze()
else:
    x_train_source = pd.read_csv(f'../data/{species}_xtrain.csv', index_col=0)
    y_train_source = pd.read_csv(f'../data/{species}_ytrain.csv', index_col=0).squeeze()
    x_test_source = pd.read_csv(f'../data/{species}_xtest.csv', index_col=0)
    y_test_source = pd.read_csv(f'../data/{species}_ytest.csv', index_col=0).squeeze()
    
product_class_source = pd.read_csv(f'../data/{species}_product_class.csv', index_col=0)
print(x_train_source.shape)

# target
species = 'RT'
if if_scale:
    x_train_target = pd.read_csv(f'../data/{species}_xtrain_scaled.csv', index_col=0)
    y_train_target = pd.read_csv(f'../data/{species}_ytrain_scaled.csv', index_col=0).squeeze()
    x_test_target = pd.read_csv(f'../data/{species}_xtest_scaled.csv', index_col=0)
    y_test_target = pd.read_csv(f'../data/{species}_ytest_scaled.csv', index_col=0).squeeze()
else:
    x_train_target = pd.read_csv(f'../data/{species}_xtrain.csv', index_col=0)
    y_train_target = pd.read_csv(f'../data/{species}_ytrain.csv', index_col=0).squeeze()
    x_test_target = pd.read_csv(f'../data/{species}_xtest.csv', index_col=0)
    y_test_target = pd.read_csv(f'../data/{species}_ytest.csv', index_col=0).squeeze()
    
product_class_target = pd.read_csv(f'../data/{species}_product_class.csv', index_col=0)
#print(x_train_target.drop(columns=['plot']).shape)
# Out:
# (3752, 28)

# %%
# fit model on source dataset
model, history = fit_model(x_train_source, y_train_source, x_test_source, y_test_source)
encoded_source = model.predict(x_train_source)
#summarize_model(model, history, x_train_source, y_train_source, x_test_source, y_test_source, './figures/source-mlp.jpg')

# save model to file
model.save('encoder.h5')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 50)                1450
#
#  dense_4 (Dense)             (None, 28)                1428
#
#  dense_5 (Dense)             (None, 14)                406
#
# =================================================================
# Total params: 3,284
# Trainable params: 3,284
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000002020378EDC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000002020378EDC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 118/118 [==============================] - ETA: 0s - loss: 3255622.5000 - mean_absolute_percentage_error: 11475138560.0000WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x00000201C1455708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x00000201C1455708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 118/118 [==============================] - 1s 4ms/step - loss: 3255622.5000 - mean_absolute_percentage_error: 11475138560.0000 - val_loss: 2220.8787 - val_mean_absolute_percentage_error: 624236032.0000
# Epoch 2/100
# 118/118 [==============================] - 0s 3ms/step - loss: 1288.9142 - mean_absolute_percentage_error: 405252128.0000 - val_loss: 521.7966 - val_mean_absolute_percentage_error: 154110016.0000
# Epoch 3/100
# 118/118 [==============================] - 0s 3ms/step - loss: 589.7621 - mean_absolute_percentage_error: 96100504.0000 - val_loss: 426.1553 - val_mean_absolute_percentage_error: 39909968.0000
# Epoch 4/100
# 118/118 [==============================] - 0s 3ms/step - loss: 560.7136 - mean_absolute_percentage_error: 54157148.0000 - val_loss: 413.7000 - val_mean_absolute_percentage_error: 28765354.0000
# Epoch 5/100
# 118/118 [==============================] - 0s 4ms/step - loss: 554.5345 - mean_absolute_percentage_error: 39545628.0000 - val_loss: 409.4368 - val_mean_absolute_percentage_error: 25122964.0000
# Epoch 6/100
# 118/118 [==============================] - 0s 3ms/step - loss: 551.2691 - mean_absolute_percentage_error: 37556444.0000 - val_loss: 407.1447 - val_mean_absolute_percentage_error: 21067460.0000
# Epoch 7/100
# 118/118 [==============================] - 0s 3ms/step - loss: 549.2259 - mean_absolute_percentage_error: 33095422.0000 - val_loss: 405.2379 - val_mean_absolute_percentage_error: 18475242.0000
# Epoch 8/100
# 118/118 [==============================] - 0s 3ms/step - loss: 547.3934 - mean_absolute_percentage_error: 35107940.0000 - val_loss: 402.2245 - val_mean_absolute_percentage_error: 12240137.0000
# Epoch 9/100
# 118/118 [==============================] - 0s 3ms/step - loss: 545.2855 - mean_absolute_percentage_error: 31775700.0000 - val_loss: 399.7588 - val_mean_absolute_percentage_error: 14043510.0000
# Epoch 10/100
# 118/118 [==============================] - 0s 3ms/step - loss: 543.6856 - mean_absolute_percentage_error: 40315748.0000 - val_loss: 396.9782 - val_mean_absolute_percentage_error: 15368975.0000
# Epoch 11/100
# 118/118 [==============================] - 0s 3ms/step - loss: 536.2257 - mean_absolute_percentage_error: 51447888.0000 - val_loss: 391.5590 - val_mean_absolute_percentage_error: 22261702.0000
# Epoch 12/100
# 118/118 [==============================] - 0s 3ms/step - loss: 532.7385 - mean_absolute_percentage_error: 61258668.0000 - val_loss: 391.2102 - val_mean_absolute_percentage_error: 29544760.0000
# Epoch 13/100
# 118/118 [==============================] - 0s 3ms/step - loss: 530.4068 - mean_absolute_percentage_error: 55752828.0000 - val_loss: 392.2438 - val_mean_absolute_percentage_error: 33797424.0000
# Epoch 14/100
# 118/118 [==============================] - 0s 3ms/step - loss: 528.8144 - mean_absolute_percentage_error: 56467364.0000 - val_loss: 391.7894 - val_mean_absolute_percentage_error: 26312012.0000
# Epoch 15/100
# 118/118 [==============================] - 0s 4ms/step - loss: 526.2578 - mean_absolute_percentage_error: 56590100.0000 - val_loss: 391.0641 - val_mean_absolute_percentage_error: 37491200.0000
# Epoch 16/100
# 118/118 [==============================] - 0s 3ms/step - loss: 522.5595 - mean_absolute_percentage_error: 69773752.0000 - val_loss: 391.2201 - val_mean_absolute_percentage_error: 43335696.0000
# Epoch 17/100
# 118/118 [==============================] - 0s 3ms/step - loss: 520.7530 - mean_absolute_percentage_error: 76003720.0000 - val_loss: 388.7491 - val_mean_absolute_percentage_error: 20357780.0000
# Epoch 18/100
# 118/118 [==============================] - 0s 3ms/step - loss: 519.5384 - mean_absolute_percentage_error: 60421376.0000 - val_loss: 382.6413 - val_mean_absolute_percentage_error: 25086078.0000
# Epoch 19/100
# 118/118 [==============================] - 0s 3ms/step - loss: 514.0177 - mean_absolute_percentage_error: 73502584.0000 - val_loss: 381.4611 - val_mean_absolute_percentage_error: 26775126.0000
# Epoch 20/100
# 118/118 [==============================] - 0s 3ms/step - loss: 515.3249 - mean_absolute_percentage_error: 72949984.0000 - val_loss: 378.3478 - val_mean_absolute_percentage_error: 17466542.0000
# Epoch 21/100
# 118/118 [==============================] - 0s 3ms/step - loss: 512.1368 - mean_absolute_percentage_error: 70759472.0000 - val_loss: 377.5106 - val_mean_absolute_percentage_error: 22977660.0000
# Epoch 22/100
# 118/118 [==============================] - 0s 3ms/step - loss: 508.5307 - mean_absolute_percentage_error: 74429464.0000 - val_loss: 375.8608 - val_mean_absolute_percentage_error: 25649538.0000
# Epoch 23/100
# 118/118 [==============================] - 0s 3ms/step - loss: 507.1983 - mean_absolute_percentage_error: 74531952.0000 - val_loss: 377.9472 - val_mean_absolute_percentage_error: 32340876.0000
# Epoch 24/100
# 118/118 [==============================] - 0s 3ms/step - loss: 506.7660 - mean_absolute_percentage_error: 86928008.0000 - val_loss: 375.1380 - val_mean_absolute_percentage_error: 21325988.0000
# Epoch 25/100
# 118/118 [==============================] - 0s 3ms/step - loss: 503.0860 - mean_absolute_percentage_error: 83761976.0000 - val_loss: 376.5367 - val_mean_absolute_percentage_error: 40291364.0000
# Epoch 26/100
# 118/118 [==============================] - 0s 3ms/step - loss: 502.8761 - mean_absolute_percentage_error: 93303416.0000 - val_loss: 370.2912 - val_mean_absolute_percentage_error: 26095702.0000
# Epoch 27/100
# 118/118 [==============================] - 0s 3ms/step - loss: 499.2003 - mean_absolute_percentage_error: 85340368.0000 - val_loss: 370.4797 - val_mean_absolute_percentage_error: 24358908.0000
# Epoch 28/100
# 118/118 [==============================] - 0s 3ms/step - loss: 498.6961 - mean_absolute_percentage_error: 79921048.0000 - val_loss: 369.8686 - val_mean_absolute_percentage_error: 21645850.0000
# Epoch 29/100
# 118/118 [==============================] - 0s 3ms/step - loss: 493.9778 - mean_absolute_percentage_error: 89321024.0000 - val_loss: 365.9593 - val_mean_absolute_percentage_error: 20824180.0000
# Epoch 30/100
# 118/118 [==============================] - 0s 3ms/step - loss: 493.4504 - mean_absolute_percentage_error: 93882872.0000 - val_loss: 367.3711 - val_mean_absolute_percentage_error: 30839670.0000
# Epoch 31/100
# 118/118 [==============================] - 0s 3ms/step - loss: 489.4615 - mean_absolute_percentage_error: 100829968.0000 - val_loss: 360.2167 - val_mean_absolute_percentage_error: 26018952.0000
# Epoch 32/100
# 118/118 [==============================] - 0s 3ms/step - loss: 482.9658 - mean_absolute_percentage_error: 98067608.0000 - val_loss: 363.4657 - val_mean_absolute_percentage_error: 15696599.0000
# Epoch 33/100
# 118/118 [==============================] - 0s 3ms/step - loss: 481.1548 - mean_absolute_percentage_error: 94357736.0000 - val_loss: 359.3510 - val_mean_absolute_percentage_error: 45254316.0000
# Epoch 34/100
# 118/118 [==============================] - 0s 3ms/step - loss: 481.6178 - mean_absolute_percentage_error: 102482120.0000 - val_loss: 366.1057 - val_mean_absolute_percentage_error: 13303130.0000
# Epoch 35/100
# 118/118 [==============================] - 0s 3ms/step - loss: 479.2050 - mean_absolute_percentage_error: 103555848.0000 - val_loss: 357.0876 - val_mean_absolute_percentage_error: 23758768.0000
# Epoch 36/100
# 118/118 [==============================] - 0s 3ms/step - loss: 476.8177 - mean_absolute_percentage_error: 93122696.0000 - val_loss: 352.1777 - val_mean_absolute_percentage_error: 31460562.0000
# Epoch 37/100
# 118/118 [==============================] - 0s 3ms/step - loss: 472.3157 - mean_absolute_percentage_error: 104983280.0000 - val_loss: 350.8132 - val_mean_absolute_percentage_error: 41388908.0000
# Epoch 38/100
# 118/118 [==============================] - 0s 3ms/step - loss: 473.0930 - mean_absolute_percentage_error: 92701000.0000 - val_loss: 357.2440 - val_mean_absolute_percentage_error: 47407036.0000
# Epoch 39/100
# 118/118 [==============================] - 0s 3ms/step - loss: 470.9974 - mean_absolute_percentage_error: 100698584.0000 - val_loss: 349.9561 - val_mean_absolute_percentage_error: 16823014.0000
# Epoch 40/100
# 118/118 [==============================] - 0s 3ms/step - loss: 471.7621 - mean_absolute_percentage_error: 99630272.0000 - val_loss: 353.3403 - val_mean_absolute_percentage_error: 47438792.0000
# Epoch 41/100
# 118/118 [==============================] - 0s 3ms/step - loss: 469.3441 - mean_absolute_percentage_error: 101275136.0000 - val_loss: 346.8442 - val_mean_absolute_percentage_error: 34379828.0000
# Epoch 42/100
# 118/118 [==============================] - 0s 3ms/step - loss: 467.8723 - mean_absolute_percentage_error: 97573984.0000 - val_loss: 348.1380 - val_mean_absolute_percentage_error: 40610564.0000
# Epoch 43/100
# 118/118 [==============================] - 0s 3ms/step - loss: 465.8280 - mean_absolute_percentage_error: 90376064.0000 - val_loss: 347.0051 - val_mean_absolute_percentage_error: 25877446.0000
# Epoch 44/100
# 118/118 [==============================] - 0s 3ms/step - loss: 465.7061 - mean_absolute_percentage_error: 99624080.0000 - val_loss: 361.6699 - val_mean_absolute_percentage_error: 62187084.0000
# Epoch 45/100
# 118/118 [==============================] - 0s 3ms/step - loss: 465.9055 - mean_absolute_percentage_error: 101742928.0000 - val_loss: 342.8609 - val_mean_absolute_percentage_error: 19570474.0000
# Epoch 46/100
# 118/118 [==============================] - 0s 3ms/step - loss: 464.8312 - mean_absolute_percentage_error: 99210688.0000 - val_loss: 344.2011 - val_mean_absolute_percentage_error: 25330238.0000
# Epoch 47/100
# 118/118 [==============================] - 0s 3ms/step - loss: 465.4138 - mean_absolute_percentage_error: 91104304.0000 - val_loss: 346.5298 - val_mean_absolute_percentage_error: 39716016.0000
# Epoch 48/100
# 118/118 [==============================] - 0s 3ms/step - loss: 463.8006 - mean_absolute_percentage_error: 86678432.0000 - val_loss: 343.2718 - val_mean_absolute_percentage_error: 38215836.0000
# Epoch 49/100
# 118/118 [==============================] - 0s 3ms/step - loss: 462.5137 - mean_absolute_percentage_error: 96331160.0000 - val_loss: 347.6932 - val_mean_absolute_percentage_error: 38430676.0000
# Epoch 50/100
# 118/118 [==============================] - 0s 3ms/step - loss: 464.1447 - mean_absolute_percentage_error: 86656384.0000 - val_loss: 348.0399 - val_mean_absolute_percentage_error: 44217432.0000
# Epoch 51/100
# 118/118 [==============================] - 0s 3ms/step - loss: 469.4095 - mean_absolute_percentage_error: 82163152.0000 - val_loss: 349.6623 - val_mean_absolute_percentage_error: 51499804.0000
# Epoch 52/100
# 118/118 [==============================] - 0s 3ms/step - loss: 466.5463 - mean_absolute_percentage_error: 89476696.0000 - val_loss: 354.0266 - val_mean_absolute_percentage_error: 12763818.0000
# Epoch 53/100
# 118/118 [==============================] - 0s 3ms/step - loss: 463.7813 - mean_absolute_percentage_error: 88865904.0000 - val_loss: 348.4923 - val_mean_absolute_percentage_error: 13653591.0000
# Epoch 54/100
# 118/118 [==============================] - 0s 3ms/step - loss: 462.4233 - mean_absolute_percentage_error: 87298016.0000 - val_loss: 345.9681 - val_mean_absolute_percentage_error: 28363640.0000
# Epoch 55/100
# 118/118 [==============================] - 0s 3ms/step - loss: 459.7765 - mean_absolute_percentage_error: 92994688.0000 - val_loss: 341.0823 - val_mean_absolute_percentage_error: 35379752.0000
# Epoch 56/100
# 118/118 [==============================] - 0s 3ms/step - loss: 460.2300 - mean_absolute_percentage_error: 80197376.0000 - val_loss: 341.9062 - val_mean_absolute_percentage_error: 23347464.0000
# Epoch 57/100
# 118/118 [==============================] - 0s 3ms/step - loss: 460.2964 - mean_absolute_percentage_error: 90214912.0000 - val_loss: 339.2818 - val_mean_absolute_percentage_error: 24019226.0000
# Epoch 58/100
# 118/118 [==============================] - 0s 3ms/step - loss: 458.8183 - mean_absolute_percentage_error: 86579208.0000 - val_loss: 338.7316 - val_mean_absolute_percentage_error: 25339672.0000
# Epoch 59/100
# 118/118 [==============================] - 0s 3ms/step - loss: 460.0451 - mean_absolute_percentage_error: 89720808.0000 - val_loss: 349.0468 - val_mean_absolute_percentage_error: 13649799.0000
# Epoch 60/100
# 118/118 [==============================] - 0s 3ms/step - loss: 458.6843 - mean_absolute_percentage_error: 91690568.0000 - val_loss: 340.8719 - val_mean_absolute_percentage_error: 30521086.0000
# Epoch 61/100
# 118/118 [==============================] - 0s 3ms/step - loss: 464.8114 - mean_absolute_percentage_error: 77258600.0000 - val_loss: 342.4535 - val_mean_absolute_percentage_error: 19993250.0000
# Epoch 62/100
# 118/118 [==============================] - 0s 3ms/step - loss: 459.5731 - mean_absolute_percentage_error: 102424328.0000 - val_loss: 340.3223 - val_mean_absolute_percentage_error: 24860680.0000
# Epoch 63/100
# 118/118 [==============================] - 0s 3ms/step - loss: 459.1588 - mean_absolute_percentage_error: 96910728.0000 - val_loss: 336.3414 - val_mean_absolute_percentage_error: 26356894.0000
# Epoch 64/100
# 118/118 [==============================] - 0s 3ms/step - loss: 455.1766 - mean_absolute_percentage_error: 89136744.0000 - val_loss: 338.6520 - val_mean_absolute_percentage_error: 23602232.0000
# Epoch 65/100
# 118/118 [==============================] - 0s 3ms/step - loss: 453.2809 - mean_absolute_percentage_error: 108590752.0000 - val_loss: 333.0588 - val_mean_absolute_percentage_error: 39336000.0000
# Epoch 66/100
# 118/118 [==============================] - 0s 3ms/step - loss: 452.1911 - mean_absolute_percentage_error: 88558112.0000 - val_loss: 335.4142 - val_mean_absolute_percentage_error: 31314440.0000
# Epoch 67/100
# 118/118 [==============================] - 0s 3ms/step - loss: 451.0423 - mean_absolute_percentage_error: 88085992.0000 - val_loss: 329.1685 - val_mean_absolute_percentage_error: 22699200.0000
# Epoch 68/100
# 118/118 [==============================] - 0s 3ms/step - loss: 451.8188 - mean_absolute_percentage_error: 83105848.0000 - val_loss: 335.5058 - val_mean_absolute_percentage_error: 46212672.0000
# Epoch 69/100
# 118/118 [==============================] - 0s 3ms/step - loss: 445.7857 - mean_absolute_percentage_error: 102902016.0000 - val_loss: 327.7901 - val_mean_absolute_percentage_error: 39650300.0000
# Epoch 70/100
# 118/118 [==============================] - 0s 3ms/step - loss: 444.9281 - mean_absolute_percentage_error: 89980224.0000 - val_loss: 357.7565 - val_mean_absolute_percentage_error: 75864984.0000
# Epoch 71/100
# 118/118 [==============================] - 0s 3ms/step - loss: 448.1288 - mean_absolute_percentage_error: 104269760.0000 - val_loss: 330.9852 - val_mean_absolute_percentage_error: 43076024.0000
# Epoch 72/100
# 118/118 [==============================] - 0s 3ms/step - loss: 446.3926 - mean_absolute_percentage_error: 97969024.0000 - val_loss: 327.6167 - val_mean_absolute_percentage_error: 23936624.0000
# Epoch 73/100
# 118/118 [==============================] - 0s 3ms/step - loss: 445.2352 - mean_absolute_percentage_error: 89119944.0000 - val_loss: 326.4792 - val_mean_absolute_percentage_error: 22096972.0000
# Epoch 74/100
# 118/118 [==============================] - 0s 3ms/step - loss: 447.5079 - mean_absolute_percentage_error: 92199160.0000 - val_loss: 331.7900 - val_mean_absolute_percentage_error: 45637776.0000
# Epoch 75/100
# 118/118 [==============================] - 0s 3ms/step - loss: 441.3821 - mean_absolute_percentage_error: 91765032.0000 - val_loss: 325.8166 - val_mean_absolute_percentage_error: 18509284.0000
# Epoch 76/100
# 118/118 [==============================] - 0s 3ms/step - loss: 440.6369 - mean_absolute_percentage_error: 88804768.0000 - val_loss: 327.2264 - val_mean_absolute_percentage_error: 36621016.0000
# Epoch 77/100
# 118/118 [==============================] - 0s 3ms/step - loss: 444.1367 - mean_absolute_percentage_error: 88942568.0000 - val_loss: 332.9674 - val_mean_absolute_percentage_error: 42749656.0000
# Epoch 78/100
# 118/118 [==============================] - 0s 3ms/step - loss: 440.9997 - mean_absolute_percentage_error: 92092200.0000 - val_loss: 327.4349 - val_mean_absolute_percentage_error: 22313298.0000
# Epoch 79/100
# 118/118 [==============================] - 0s 3ms/step - loss: 444.2406 - mean_absolute_percentage_error: 89322312.0000 - val_loss: 328.5476 - val_mean_absolute_percentage_error: 23515760.0000
# Epoch 80/100
# 118/118 [==============================] - 0s 3ms/step - loss: 439.1768 - mean_absolute_percentage_error: 97078472.0000 - val_loss: 327.2958 - val_mean_absolute_percentage_error: 39753700.0000
# Epoch 81/100
# 118/118 [==============================] - 0s 3ms/step - loss: 448.5090 - mean_absolute_percentage_error: 96576136.0000 - val_loss: 328.7384 - val_mean_absolute_percentage_error: 23069242.0000
# Epoch 82/100
# 118/118 [==============================] - 0s 3ms/step - loss: 441.6833 - mean_absolute_percentage_error: 86351288.0000 - val_loss: 329.5670 - val_mean_absolute_percentage_error: 35651580.0000
# Epoch 83/100
# 118/118 [==============================] - 0s 3ms/step - loss: 446.7551 - mean_absolute_percentage_error: 79297408.0000 - val_loss: 366.2193 - val_mean_absolute_percentage_error: 80273056.0000
# Epoch 84/100
# 118/118 [==============================] - 0s 3ms/step - loss: 444.9746 - mean_absolute_percentage_error: 81448936.0000 - val_loss: 323.8816 - val_mean_absolute_percentage_error: 23490848.0000
# Epoch 85/100
# 118/118 [==============================] - 0s 3ms/step - loss: 441.6082 - mean_absolute_percentage_error: 83766792.0000 - val_loss: 335.4215 - val_mean_absolute_percentage_error: 16609450.0000
# Epoch 86/100
# 118/118 [==============================] - 0s 3ms/step - loss: 446.3628 - mean_absolute_percentage_error: 87672312.0000 - val_loss: 331.6049 - val_mean_absolute_percentage_error: 29653230.0000
# Epoch 87/100
# 118/118 [==============================] - 0s 3ms/step - loss: 440.7255 - mean_absolute_percentage_error: 99618536.0000 - val_loss: 325.9268 - val_mean_absolute_percentage_error: 33090746.0000
# Epoch 88/100
# 118/118 [==============================] - 0s 3ms/step - loss: 438.8653 - mean_absolute_percentage_error: 96388208.0000 - val_loss: 332.4999 - val_mean_absolute_percentage_error: 13999482.0000
# Epoch 89/100
# 118/118 [==============================] - 0s 3ms/step - loss: 443.9421 - mean_absolute_percentage_error: 82069776.0000 - val_loss: 327.8418 - val_mean_absolute_percentage_error: 32798784.0000
# Epoch 90/100
# 118/118 [==============================] - 0s 3ms/step - loss: 443.8994 - mean_absolute_percentage_error: 64965600.0000 - val_loss: 344.9684 - val_mean_absolute_percentage_error: 65524740.0000
# Epoch 91/100
# 118/118 [==============================] - 0s 3ms/step - loss: 436.7840 - mean_absolute_percentage_error: 94126592.0000 - val_loss: 325.2462 - val_mean_absolute_percentage_error: 17709932.0000
# Epoch 92/100
# 118/118 [==============================] - 0s 3ms/step - loss: 437.3729 - mean_absolute_percentage_error: 91802832.0000 - val_loss: 333.4226 - val_mean_absolute_percentage_error: 15625442.0000
# Epoch 93/100
# 118/118 [==============================] - 0s 3ms/step - loss: 437.2655 - mean_absolute_percentage_error: 91379480.0000 - val_loss: 328.1836 - val_mean_absolute_percentage_error: 21226236.0000
# Epoch 94/100
# 118/118 [==============================] - 0s 3ms/step - loss: 438.7091 - mean_absolute_percentage_error: 85110248.0000 - val_loss: 330.5665 - val_mean_absolute_percentage_error: 35640576.0000
# Epoch 95/100
# 118/118 [==============================] - 0s 3ms/step - loss: 436.8512 - mean_absolute_percentage_error: 90941072.0000 - val_loss: 325.2949 - val_mean_absolute_percentage_error: 26305186.0000
# Epoch 96/100
# 118/118 [==============================] - 0s 3ms/step - loss: 443.9742 - mean_absolute_percentage_error: 86773504.0000 - val_loss: 328.8272 - val_mean_absolute_percentage_error: 36539452.0000
# Epoch 97/100
# 118/118 [==============================] - 0s 3ms/step - loss: 437.7815 - mean_absolute_percentage_error: 85095072.0000 - val_loss: 325.5844 - val_mean_absolute_percentage_error: 37707600.0000
# Epoch 98/100
# 118/118 [==============================] - 0s 3ms/step - loss: 439.4255 - mean_absolute_percentage_error: 96241584.0000 - val_loss: 333.9691 - val_mean_absolute_percentage_error: 41588080.0000
# Epoch 99/100
# 118/118 [==============================] - 0s 3ms/step - loss: 435.7665 - mean_absolute_percentage_error: 83296840.0000 - val_loss: 348.9573 - val_mean_absolute_percentage_error: 59819480.0000
# Epoch 100/100
# 118/118 [==============================] - 0s 3ms/step - loss: 434.1664 - mean_absolute_percentage_error: 91760552.0000 - val_loss: 326.3440 - val_mean_absolute_percentage_error: 42905108.0000
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020208C0F4C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020208C0F4C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 118/118 [==============================] - 0s 873us/step

# %%
model = load_model('encoder.h5')

model.fit(x_train_target.drop(columns=['Species']), y_train_target, validation_data=(x_test_target.drop(columns=['Species']), y_test_target), epochs=10)

# predict encoded target data
encoded_target = model.predict(x_train_target.drop(columns=['Species']))
# Out:
# Epoch 1/10
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020208EA3558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020208EA3558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
#  1/11 [=>............................] - ETA: 1s - loss: 53.0370 - mean_absolute_percentage_error: 116.2630WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000020208ED68B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000020208ED68B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 11/11 [==============================] - 0s 16ms/step - loss: 380.4842 - mean_absolute_percentage_error: 173.0089 - val_loss: 120.3517 - val_mean_absolute_percentage_error: 99.7419
# Epoch 2/10
# 11/11 [==============================] - 0s 6ms/step - loss: 112.4633 - mean_absolute_percentage_error: 106.5672 - val_loss: 121.1602 - val_mean_absolute_percentage_error: 99.9231
# Epoch 3/10
# 11/11 [==============================] - 0s 6ms/step - loss: 107.3177 - mean_absolute_percentage_error: 99.6997 - val_loss: 121.2419 - val_mean_absolute_percentage_error: 99.9180
# Epoch 4/10
# 11/11 [==============================] - 0s 6ms/step - loss: 106.8478 - mean_absolute_percentage_error: 99.1813 - val_loss: 121.2413 - val_mean_absolute_percentage_error: 99.9152
# Epoch 5/10
# 11/11 [==============================] - 0s 7ms/step - loss: 106.8288 - mean_absolute_percentage_error: 99.0889 - val_loss: 121.2412 - val_mean_absolute_percentage_error: 99.9143
# Epoch 6/10
# 11/11 [==============================] - 0s 8ms/step - loss: 106.8085 - mean_absolute_percentage_error: 99.0862 - val_loss: 121.2420 - val_mean_absolute_percentage_error: 99.9182
# Epoch 7/10
# 11/11 [==============================] - 0s 7ms/step - loss: 106.7885 - mean_absolute_percentage_error: 99.0830 - val_loss: 121.2432 - val_mean_absolute_percentage_error: 99.9210
# Epoch 8/10
# 11/11 [==============================] - 0s 8ms/step - loss: 106.7686 - mean_absolute_percentage_error: 99.0805 - val_loss: 121.2429 - val_mean_absolute_percentage_error: 99.9245
# Epoch 9/10
# 11/11 [==============================] - 0s 6ms/step - loss: 106.7507 - mean_absolute_percentage_error: 99.0776 - val_loss: 121.2165 - val_mean_absolute_percentage_error: 99.9237
# Epoch 10/10
# 11/11 [==============================] - 0s 6ms/step - loss: 106.7299 - mean_absolute_percentage_error: 99.0749 - val_loss: 121.1990 - val_mean_absolute_percentage_error: 99.9231
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020210D954C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020210D954C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 11/11 [==============================] - 0s 1ms/step

# %% [markdown]
# ## Models for pretrained encoder & autoencoder (pytorch)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, TensorDataset
from torchvision import datasets, transforms
from scipy.spatial.distance import pdist, squareform
from tqdm import tqdm
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler

def normalize_2d(tensor, mean, std):
    tensor = tensor - mean[:, None]
    tensor = tensor / std[:, None]
    return tensor

class SourceDataset(Dataset):
    def __init__(self, dataframe, x_features, to_predict, mean=None, std=None):
        self.dataframe = dataframe
        self.x_features = x_features
        self.to_predict = to_predict
        self.mean = mean
        self.std = std

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, index):
        data = np.array(self.dataframe.iloc[index][self.x_features])
        label = np.array(self.dataframe.iloc[index][self.to_predict])
        
        data = torch.tensor(data, dtype=torch.float32)
        if self.mean is not None and self.std is not None:
            data = normalize_1d(data, self.mean, self.std)

        return data, label

# %%
# euclidean
class TripletLoss(nn.Module):
    def __init__(self, margin=1.0):
        super(TripletLoss, self).__init__()
        self.margin = margin

    def forward(self, anchor: torch.Tensor, positive: torch.Tensor, negative: torch.Tensor) -> torch.Tensor:
        distance_positive = (anchor - positive).pow(2).sum(1)
        distance_negative = (anchor - negative).pow(2).sum(1)
        #print(distance_positive - distance_negative)
        losses = torch.relu(distance_positive - distance_negative + self.margin)
        return losses.mean()

class Autoencoder(nn.Module):
    def __init__(self, input_size, hidden_size, latent_size):
        super(Autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_size, hidden_size),
            nn.BatchNorm1d(hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, latent_size),
            nn.BatchNorm1d(latent_size),
            nn.ReLU()
        )
        self.decoder = nn.Sequential(
            nn.Linear(latent_size, hidden_size),
            nn.BatchNorm1d(hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, input_size),
            nn.BatchNorm1d(input_size),
            nn.ReLU()
        )
        self.regressor = nn.Linear(latent_size, 1)
        
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight, mode='fan_in', nonlinearity='relu')

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        regression_output = self.regressor(encoded)
        return decoded, regression_output

# custom Euclidean distance
def euclidean_distance(x1, x2):
    return torch.sqrt(torch.sum((x1 - x2) ** 2, dim=-1))

batch_size = 64


# source
to_predict = 'Product titer (g/L)'
source_species = 'Yarrowia'
target_species = 'Rhodo'

df = pd.read_excel("../impactDB/TL training data YL.xlsx", header=1)

# Count the semicolons in 'genes_modified_updated'
df['Genes modified'] = df['Genes modified'].fillna('').apply(lambda x: x.count(';'))

# Count the ones in 'gene_overexpression' and 'heterologous_gene'
df['Genes overexpressed'] = df['Genes overexpressed'].fillna('').apply(lambda x: str(x).count('1'))
df['Heterologous genes'] = df['Heterologous genes'].fillna('').apply(lambda x: str(x).count('1'))
df['Genes deleted'] = df['Genes deleted'].fillna('').apply(lambda x: str(x).count('1'))

# Remove 'dataID' and 'paper_number' columns
df = df.drop(['dataID', 'paper_number','product_name'], axis=1)

# Impute all NaN data as zero
imputer = SimpleImputer(strategy='constant', fill_value=0)
df_imputed = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

scaler = MinMaxScaler()

# Fit and transform the original DataFrame
df_scaled = pd.DataFrame(scaler.fit_transform(df_imputed), columns=df_imputed.columns)

#row_sums = df_imputed.sum(axis=1)
#source_norm = df_imputed / row_sums[:, np.newaxis]
x_source = df_scaled.drop([to_predict], axis=1)

# Calculate pairwise Euclidean distances
distances = pdist(df_imputed.values, metric='euclidean')
# excluding the anchor itself
pairwise_distances = squareform(distances) + np.eye(len(df_scaled)) * 1e10
pairwise_distances_neg = squareform(distances)
print(pairwise_distances.shape)

triplets_source = []
with tqdm(total=len(df_imputed)) as progress_bar:
    for i, anchor in x_source.iterrows():
        # positive sample = closest to the anchor
        positive_idx = np.argmin(pairwise_distances[i])
        positive = x_source.iloc[positive_idx]

        # negative sample = farthest from the anchor
        negative_idx = np.argmax(pairwise_distances_neg[i])
        negative = x_source.iloc[negative_idx]

        triplets_source.append((anchor, positive, negative))
        progress_bar.update(1)
triplets_array = np.array(triplets_source)
triplet_data = torch.tensor(triplets_array, dtype=torch.float32)
print(triplet_data.shape)

dataset = TensorDataset(triplet_data)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
# Out:
#  20%|███████████████▌                                                             | 946/4690 [00:00<00:00, 9451.74it/s]
# (4690, 4690)
# 100%|████████████████████████████████████████████████████████████████████████████| 4690/4690 [00:00<00:00, 6904.51it/s]
# torch.Size([4690, 3, 29])

# %%
# pre-training
input_dim = x_source.shape[1]
num_epochs = 10
learning_rate = 0.0001
hidden_dim = 64
latent_dim = 28
l1_weight = 0.1

ae = Autoencoder(input_dim, hidden_dim, latent_dim)
triplet_loss = TripletLoss()
#triplet_loss = nn.TripletMarginWithDistanceLoss(distance_function=nn.PairwiseDistance(), margin=1)
optimizer = optim.Adam(ae.parameters(), lr=learning_rate)

for epoch in range(num_epochs):
    for triplets in dataloader:
        triplets = triplets[0]
        #print(triplets)
        anchors, positives, negatives = triplets[:, 0, :], triplets[:, 1, :], triplets[:, 2, :]

        anchors_encoded = ae(anchors)
        positives_encoded = ae(positives)
        negatives_encoded = ae(negatives)

        loss = triplet_loss(anchors_encoded, positives_encoded, negatives_encoded)
        
        l1_penalty = torch.norm(ae.encoder[2].weight, p=1)
        l1_penalty += torch.norm(ae.decoder[2].weight, p=1)

        total_loss = loss + l1_weight * l1_penalty

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')

torch.save(ae.encoder.state_dict(), 'pretrained_ae.pth')
# Out:
# Epoch [1/10], Loss: 0.9501
# Epoch [2/10], Loss: 0.2906
# Epoch [3/10], Loss: 0.0101
# Epoch [4/10], Loss: 0.0349
# Epoch [5/10], Loss: 0.0219
# Epoch [6/10], Loss: 0.0210
# Epoch [7/10], Loss: 0.0000
# Epoch [8/10], Loss: 0.0000
# Epoch [9/10], Loss: 0.0012
# Epoch [10/10], Loss: 0.0000

# %%
# target
df = pd.read_excel("../impactDB/TL training data RT.xlsx", header=1)

# Set the target column
target = 'Product_titer(g/L)'
species = 'Rhodo'

# Count the semicolons in 'genes_modified_updated'
df['genes_modified_updated'] = df['genes_modified_updated'].fillna('').apply(lambda x: x.count(';'))

# Count the ones in 'gene_overexpression' and 'heterologous_gene'
df['gene_overexpression'] = df['gene_overexpression'].apply(lambda x: 1 if x == 1 else 0)
df['heterologous_gene'] = df['heterologous_gene'].apply(lambda x: 1 if x == 1 else 0)
df['gene_deletion'] = df['gene_deletion'].apply(lambda x: 1 if x == 1 else 0)

# Remove 'dataID' and 'paper_number' columns
df = df.drop(['dataID', 'paper_number','product_name'], axis=1)

# Impute all NaN data as zero
imputer = SimpleImputer(strategy='constant', fill_value=0)
df_imputed = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

scaler = MinMaxScaler()

# Fit and transform the original DataFrame
df_scaled = pd.DataFrame(scaler.fit_transform(df_imputed), columns=df_imputed.columns)

#row_sums = df_imputed.sum(axis=1)
#target_norm = df_imputed / row_sums[:, np.newaxis]
x_target = df_scaled.drop([to_predict], axis=1)
batch_size = 4

distances = pdist(df_imputed.values, metric='euclidean')
pairwise_distances = squareform(distances) + np.eye(len(df_scaled)) * 1e10
pairwise_distances_neg = squareform(distances)
print(pairwise_distances.shape)

triplets_target = []
with tqdm(total=len(df_scaled)) as progress_bar:
    for i, anchor in x_target.iterrows():
        positive_idx = np.argmin(pairwise_distances[i])
        positive = x_target.iloc[positive_idx]

        negative_idx = np.argmax(pairwise_distances_neg[i])
        negative = x_target.iloc[negative_idx]

        triplets_target.append((anchor, positive, negative))
        progress_bar.update(1)
triplets_array = np.array(triplets_target)
triplet_data = torch.tensor(triplets_array, dtype=torch.float32)
print(triplet_data.shape)

dataset = TensorDataset(triplet_data)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# transferring
transfer_autoencoder = Autoencoder(input_dim, hidden_dim, latent_dim)
transfer_autoencoder.load_state_dict(ae.state_dict())

# Reset the optimizer
optimizer = optim.Adam(transfer_autoencoder.parameters(), lr=0.001)

# encoder only
for param in transfer_autoencoder.encoder.parameters():
    param.requires_grad = False

for epoch in range(num_epochs):
    for data in dataloader:
        triplets = data[0]

        #print(triplets)
        anchors, positives, negatives = triplets[:, 0, :], triplets[:, 1, :], triplets[:, 2, :]

        anchors_encoded = transfer_autoencoder.encoder(anchors)
        positives_encoded = transfer_autoencoder.encoder(positives)
        negatives_encoded = transfer_autoencoder.encoder(negatives)
        
        anchors_decoded = transfer_autoencoder.decoder(anchors_encoded)
        positives_decoded = transfer_autoencoder.decoder(positives_encoded)
        negatives_decoded = transfer_autoencoder.decoder(negatives_encoded)

        loss = triplet_loss(anchors_decoded, positives_decoded, negatives_decoded)
        
        l1_penalty = torch.norm(transfer_autoencoder.encoder[2].weight, p=1)
        l1_penalty += torch.norm(transfer_autoencoder.decoder[2].weight, p=1)

        total_loss = loss + l1_weight * l1_penalty

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')

# save
reconstructed_anchors_list = []
reconstructed_positives_list = []
reconstructed_negatives_list = []
with torch.no_grad():
    for batch_data in dataloader:
        triplets = batch_data[0]
        anchors, positives, negatives = triplets[:, 0, :], triplets[:, 1, :], triplets[:, 2, :]

        anchors_encoded = transfer_autoencoder(anchors).detach().numpy()
        positives_encoded = transfer_autoencoder(positives).detach().numpy()
        negatives_encoded = transfer_autoencoder(negatives).detach().numpy()

        # Append the reconstructed samples to the lists
        reconstructed_anchors_list.append(anchors_encoded)
        reconstructed_positives_list.append(positives_encoded)
        reconstructed_negatives_list.append(negatives_encoded)

encoded_anchors = np.concatenate(reconstructed_anchors_list, axis=0)
encoded_df = pd.DataFrame(encoded_anchors)
encoded_df.to_csv('encoded_target_x.csv', index=False)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 443/443 [00:00<00:00, 8760.75it/s]
# (443, 443)
# torch.Size([443, 3, 28])
# Epoch [1/10], Loss: 0.0000
# Epoch [2/10], Loss: 0.0000
# Epoch [3/10], Loss: 0.0000
# Epoch [4/10], Loss: 0.0000
# Epoch [5/10], Loss: 0.0000
# Epoch [6/10], Loss: 0.0000
# Epoch [7/10], Loss: 0.0000
# Epoch [8/10], Loss: 0.0000
# Epoch [9/10], Loss: 0.0000
# Epoch [10/10], Loss: 0.0000

# %%
np.savetxt("./data/encoded_target.csv", encoded_target, delimiter=",")
np.savetxt("./data/encoded_source.csv", encode_source, delimiter=",")

# %% [markdown]
# ## Pretrain encoder only

# %%
class CustomDataset(Dataset):
    def __init__(self, data, y):
        self.data = data
        self.y = y

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        sample_data = self.data[idx]
        sample_y = self.y[idx]

        return sample_data, sample_y

batch_size = 32

to_predict = 'Product titer (g/L)'
source_species = 'Yarrowia'
target_species = 'Rhodo'

df = pd.read_excel("../impactDB/TL training data YL.xlsx", header=1)
#df = df.dropna(axis=1, how="all")

# Count the semicolons in 'genes_modified_updated'
df['Genes modified'] = df['Genes modified'].fillna('').apply(lambda x: x.count(';'))

# Count the ones in 'gene_overexpression' and 'heterologous_gene'
df['Genes overexpressed'] = df['Genes overexpressed'].fillna('').apply(lambda x: str(x).count('1'))
df['Heterologous genes'] = df['Heterologous genes'].fillna('').apply(lambda x: str(x).count('1'))
df['Genes deleted'] = df['Genes deleted'].fillna('').apply(lambda x: str(x).count('1'))

# Remove 'dataID' and 'paper_number' columns
df = df.drop(['dataID', 'paper_number','product_name'], axis=1)

# Impute all NaN data as zero
imputer = SimpleImputer(strategy='constant', fill_value=0)
df_imputed = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

scaler = MinMaxScaler()

# Fit and transform the original DataFrame
df_scaled = pd.DataFrame(scaler.fit_transform(df_imputed), columns=df_imputed.columns)

x = df_scaled.drop(to_predict, axis=1).values
y = df_scaled[[to_predict]].values

custom_dataset = CustomDataset(x, y)
dataloader = DataLoader(custom_dataset, batch_size=batch_size, shuffle=True)

input_dim = x.shape[1]
learning_rate = 0.1
hidden_dim = 30
latent_dim = 14
l1_weight = 0.1

# Add L2 regularization
weight_decay = 1e-5

ae = Autoencoder(input_dim, hidden_dim, latent_dim)
#triplet_loss = TripletLoss()
#triplet_loss = nn.TripletMarginWithDistanceLoss(distance_function=nn.PairwiseDistance(), margin=1)

mse_loss = nn.MSELoss()
l1_loss = nn.L1Loss()

optimizer = optim.Adam(ae.parameters(), lr=learning_rate, weight_decay=weight_decay)

num_epochs = 200
patience = 10
min_delta = 1e-4
best_loss = float('inf')
counter = 0

for epoch in range(num_epochs):
    epoch_loss = 0.0
    for data, y in dataloader:
        data = data.float()
        y = y.float()
        
        optimizer.zero_grad()
        decoded, regression_output = ae(data)

        reconstruction_loss = mse_loss(decoded, data)
        regression_loss = l1_loss(regression_output, y)

        combined_loss = (1-l1_weight) * reconstruction_loss + l1_weight * regression_loss

        combined_loss.backward()
        optimizer.step()
        
        epoch_loss += combined_loss.item()
        
    # Early stopping
    if best_loss - epoch_loss > min_delta:
        best_loss = epoch_loss
        counter = 0
    else:
        counter += 1

    if counter >= patience:
        print(f"Early stopping triggered at epoch {epoch+1}")
        break
    
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {combined_loss.item():.4f}')

torch.save(ae.state_dict(), 'pretrained_ae.pth')

# target
df = pd.read_excel("../impactDB/RT+YL.xlsx", header=1)
#df = df.dropna(axis=1, how="all")

# Set the target column
to_predict = 'Product titer (g/L)'

# Count the semicolons in 'genes_modified_updated'
df['Genes modified'] = df['Genes modified'].fillna('').apply(lambda x: x.count(';'))

# Count the ones in 'gene_overexpression' and 'heterologous_gene'
df['Genes overexpressed'] = df['Genes overexpressed'].fillna('').apply(lambda x: str(x).count('1'))
df['Heterologous genes'] = df['Heterologous genes'].fillna('').apply(lambda x: str(x).count('1'))
df['Genes deleted'] = df['Genes deleted'].fillna('').apply(lambda x: str(x).count('1'))

# Remove 'dataID' and 'paper_number' columns
df = df.drop(['dataID', 'paper_number','product_name'], axis=1)
# Impute all NaN data as zero
imputer = SimpleImputer(strategy='constant', fill_value=0)
df_imputed = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)


scaler = MinMaxScaler()

# Fit and transform the original DataFrame
df_scaled = pd.DataFrame(scaler.fit_transform(df_imputed), columns=df_imputed.columns)

x = df_scaled.drop(to_predict, axis=1).values
y = df_scaled[[to_predict]].values

custom_dataset = CustomDataset(x, y)
dataloader = DataLoader(custom_dataset, batch_size=batch_size, shuffle=True)



# transferring
transfer_autoencoder = Autoencoder(input_dim, hidden_dim, latent_dim)
transfer_autoencoder.encoder.load_state_dict(ae.encoder.state_dict())

for param in transfer_autoencoder.encoder.parameters():
    param.requires_grad = False

mse_loss = nn.MSELoss()
l1_loss = nn.L1Loss()

optimizer = optim.Adam(ae.parameters(), lr=learning_rate, weight_decay=weight_decay)

num_epochs = 200
patience = 10
min_delta = 1e-4
best_loss = float('inf')
counter = 0

for epoch in range(num_epochs):
    epoch_loss = 0.0
    for data, y in dataloader:
        data = data.float()
        y = y.float()
        
        optimizer.zero_grad()
        decoded, regression_output = ae(data)

        reconstruction_loss = mse_loss(decoded, data)
        regression_loss = l1_loss(regression_output, y)

        combined_loss = (1-l1_weight) * reconstruction_loss + l1_weight * regression_loss

        combined_loss.backward()
        optimizer.step()
        
        epoch_loss += combined_loss.item()
        
    # Early stopping
    if best_loss - epoch_loss > min_delta:
        best_loss = epoch_loss
        counter = 0
    else:
        counter += 1

    if counter >= patience:
        print(f"Early stopping triggered at epoch {epoch+1}")
        break
    
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {combined_loss.item():.4f}')

ae.eval()

# save
reconstructed_list = []
with torch.no_grad():
    for data, y in dataloader:
        data = data.float()
        y = y.float()
        # Forward pass
        encoded = transfer_autoencoder.(data)

        encoded = encoded.detach().numpy()

        # Append the reconstructed samples to the lists
        reconstructed_list.append(encoded)

encoded_x = np.concatenate(reconstructed_list, axis=0)
encoded_df = pd.DataFrame(encoded_x)
encoded_df.to_csv('encoded_target_x.csv', index=False)

# %% [markdown]
# ## Pretrained encoder and transfer at latent space using VAE

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, hidden_dim, latent_dim):
        super(Encoder, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2_mean = nn.Linear(hidden_dim, latent_dim)
        self.fc2_log_var = nn.Linear(hidden_dim, latent_dim)

    def forward(self, x):
        h = torch.relu(self.fc1(x))
        z_mean = self.fc2_mean(h)
        z_log_var = self.fc2_log_var(h)
        return z_mean, z_log_var

class Decoder(nn.Module):
    def __init__(self, latent_dim, hidden_dim, output_dim):
        super(Decoder, self).__init__()
        self.fc3 = nn.Linear(latent_dim, hidden_dim)
        self.fc4 = nn.Linear(hidden_dim, output_dim)

    def forward(self, z):
        h = torch.relu(self.fc3(z))
        x_recon = torch.sigmoid(self.fc4(h))
        return x_recon

class VAE(nn.Module):
    def __init__(self, input_dim, hidden_dim, latent_dim):
        super(VAE, self).__init__()
        self.encoder = Encoder(input_dim, hidden_dim, latent_dim)
        self.decoder = Decoder(latent_dim, hidden_dim, input_dim)

    def reparameterize(self, z_mean, z_log_var):
        std = torch.exp(0.5 * z_log_var)
        eps = torch.randn_like(std)
        return z_mean + eps * std

    def forward(self, x):
        z_mean, z_log_var = self.encoder(x)
        z = self.reparameterize(z_mean, z_log_var)
        x_recon = self.decoder(z)
        return x_recon, z_mean, z_log_var

# %%
device = torch.device("cuda")

batch_size = 32

to_predict = 'Product titer (g/L)'
source_species = 'Yarrowia'
target_species = 'Rhodo'

df = pd.read_excel("../impactDB/TL training data YL.xlsx", header=1)
#df = df.dropna(axis=1, how="all")

# Count the semicolons in 'genes_modified_updated'
df['Genes modified'] = df['Genes modified'].fillna('').apply(lambda x: x.count(';'))

# Count the ones in 'gene_overexpression' and 'heterologous_gene'
df['Genes overexpressed'] = df['Genes overexpressed'].fillna('').apply(lambda x: str(x).count('1'))
df['Heterologous genes'] = df['Heterologous genes'].fillna('').apply(lambda x: str(x).count('1'))
df['Genes deleted'] = df['Genes deleted'].fillna('').apply(lambda x: str(x).count('1'))

# Remove 'dataID' and 'paper_number' columns
df = df.drop(['dataID', 'paper_number','product_name'], axis=1)

# Impute all NaN data as zero
imputer = SimpleImputer(strategy='constant', fill_value=0)
df_imputed = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

scaler = MinMaxScaler()

# Fit and transform the original DataFrame
df_scaled = pd.DataFrame(scaler.fit_transform(df_imputed), columns=df_imputed.columns)

x = df_scaled.drop(to_predict, axis=1).values
y = df_scaled[[to_predict]].values

custom_dataset = CustomDataset(x, y)
dataloader = DataLoader(custom_dataset, batch_size=batch_size, shuffle=True)

input_dim = x.shape[1]
learning_rate = 0.1
hidden_dim = 30
latent_dim = 14
l1_weight = 0.1

# Add L2 regularization
weight_decay = 1e-5

model = VAE(input_dim, hidden_dim, latent_dim)
#triplet_loss = TripletLoss()
#triplet_loss = nn.TripletMarginWithDistanceLoss(distance_function=nn.PairwiseDistance(), margin=1)

mse_loss = nn.MSELoss()
l1_loss = nn.L1Loss()

optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

num_epochs = 200
patience = 10
min_delta = 1e-4
best_loss = float('inf')
counter = 0

for epoch in range(num_epochs):
    epoch_loss = 0.0
    for data, y in dataloader:
        data = data.float()
        y = y.float()
        
        optimizer.zero_grad()
        decoded, regression_output = ae(data)

        reconstruction_loss = mse_loss(decoded, data)
        regression_loss = l1_loss(regression_output, y)

        combined_loss = (1-l1_weight) * reconstruction_loss + l1_weight * regression_loss

        combined_loss.backward()
        optimizer.step()
        
        epoch_loss += combined_loss.item()
        
    # Early stopping
    if best_loss - epoch_loss > min_delta:
        best_loss = epoch_loss
        counter = 0
    else:
        counter += 1

    if counter >= patience:
        print(f"Early stopping triggered at epoch {epoch+1}")
        break
    
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {combined_loss.item():.4f}')
